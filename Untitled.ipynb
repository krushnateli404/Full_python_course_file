# %%
import pandas  as pd

# %%
df = pd.read_csv(r"C:\Users\KRUSHNA\OneDrive\Desktop\Data_science\Visulization\Pandas\locations.csv")

# %%
a = 1
type(a)
# Out:
# int

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = pd.read_csv('locations.csv',header = None)

# %%
df1
# Out:
#     0                1                                                  2   \
# 0   id  organization_id                                      accessibility
# 1    1                1       disabled_parking, ramp, restroom, wheelchair
# 2    2                1                                         wheelchair
# 3    3                1                                                NaN
# 4    4                1                                         wheelchair
# 5    5                1                                         wheelchair
# 6    6                2                       disabled_parking, wheelchair
# 7    7                2       ramp, restroom, disabled_parking, wheelchair
# 8    8                2                                                NaN
# 9    9                3                         ramp, restroom, wheelchair
# 10  10                3  elevator, tape_braille, ramp, restroom, disabl...
# ...

# %%
pd.read_csv('taxonomy.csv',names = ['a','b','c','d'])
# Out:
#                a                             b          c  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
df2 = pd.read_csv('taxonomy.csv',names = ['a','b','c'])
df2
# Out:
#                                         a          b                     c
# taxonomy_id                          name  parent_id           parent_name
# 101                             Emergency        NaN                   NaN
# 101-01                  Disaster Response        101             Emergency
# 101-02                     Emergency Cash        101             Emergency
# 101-02-01               Help Pay for Food     101-02        Emergency Cash
# ...                                   ...        ...                   ...
# 111-01-07                Workplace Rights     111-01  Advocacy & Legal Aid
# 111-02                          Mediation        111                 Legal
# 111-03                             Notary        111                 Legal
# 111-04                     Representation        111                 Legal
# 111-05       Translation & Interpretation        111                 Legal
#
# [291 rows x 3 columns]

# %%
pd.read_csv('taxonomy.csv',sep = '_')
# Out:
#                                               taxonomy  id,name,parent  \
# 0                                      101,Emergency,,             NaN
# 1               101-01,Disaster Response,101,Emergency             NaN
# 2                  101-02,Emergency Cash,101,Emergency             NaN
# 3    101-02-01,Help Pay for Food,101-02,Emergency Cash             NaN
# 4    101-02-02,Help Pay for Healthcare,101-02,Emerg...             NaN
# ..                                                 ...             ...
# 285  111-01-07,Workplace Rights,111-01,Advocacy & L...             NaN
# 286                         111-02,Mediation,111,Legal             NaN
# 287                            111-03,Notary,111,Legal             NaN
# 288                    111-04,Representation,111,Legal             NaN
# 289      111-05,Translation & Interpretation,111,Legal             NaN
#
#      id,parent  name
# 0          NaN   NaN
# 1          NaN   NaN
# 2          NaN   NaN
# 3          NaN   NaN
# ...

# %%
df2.head()
# Out:
#                              a          b               c
# taxonomy_id               name  parent_id     parent_name
# 101                  Emergency        NaN             NaN
# 101-01       Disaster Response        101       Emergency
# 101-02          Emergency Cash        101       Emergency
# 101-02-01    Help Pay for Food     101-02  Emergency Cash

# %%
df2.tail()
# Out:
#                                       a       b                     c
# 111-01-07              Workplace Rights  111-01  Advocacy & Legal Aid
# 111-02                        Mediation     111                 Legal
# 111-03                           Notary     111                 Legal
# 111-04                   Representation     111                 Legal
# 111-05     Translation & Interpretation     111                 Legal

# %%
df3 = pd.read_csv('locations.csv')
df3
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
df3.columns
# Out:
# Index(['id', 'organization_id', 'accessibility', 'admin_emails',
#        'alternate_name', 'description', 'email', 'languages', 'latitude',
#        'longitude', 'name', 'short_desc', 'transportation', 'website',
#        'virtual'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# id                   int64
# organization_id      int64
# accessibility       object
# admin_emails        object
# alternate_name      object
# description         object
# email               object
# languages           object
# latitude           float64
# longitude          float64
# name                object
# short_desc          object
# transportation      object
# website             object
# virtual               bool
# dtype: object

# %%
df3['description']
# Out:
# 0     A walk-in center for older adults that provide...
# 1     Provides training and job placement to eligibl...
# 2     Offers supportive counseling services to San M...
# 3     Provides supervised visitation services and a ...
# 4     Provides fixed 8% short term loans to eligible...
# 5     A multipurpose center offering a wide variety ...
# 6     Rosener House is a day center for older adults...
# 7     Delivers a hot meal to the home of persons age...
# 8     Provides general reading material, including b...
# 9     Provides general reading and media materials, ...
# 10    Provides general reading materials, including ...
# 11    Offers an intergenerational literacy program f...
# 12    Provides general reading materials, including ...
# 13    Provides food, clothing, bus tokens and shelte...
# 14    Provides a long-term (6-12 month) residential ...
# 15    Provides emergency assistance including food a...
# 16    Provides emergency food, clothing and furnitur...
# ...

# %%
#Question:
a =df3['description']
type(a)
# Out:
# pandas.core.series.Series

# %%
#Question:
df4 = df3[['description','email']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Question:
# ----> 2 df4 = df3[['description','email']]
#
# NameError: name 'df3' is not defined

# %%
type(df4)
# Out:
# pandas.core.frame.DataFrame

# %%
#Question:
type(df3[['name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_excel('LUSID Excel - Setting up your market data.xlsx')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
pd.read_excel('LUSID_Excel _Manage_Orders.xlsx',sheet_name = "Allocations" )
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.ExcelFile('LUSID_Excel _Manage_Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    pd.read_excel('LUSID_Excel _Manage_Orders.xlsx',sheet_name = i)

# %% [markdown]
# # read csv file data by using URL

# %%
pd.read_csv('https://gist.githubusercontent.com/fyyying/4aa5b471860321d7b47fd881898162b7/raw/6907bb3a38bfbb6fccf3a8b1edfb90e39714d14f/titanic_dataset.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
